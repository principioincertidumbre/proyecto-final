# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_acuicultura = pd.read_csv("concesiones_acuicultura_nuevas_var.csv")

# %%
#Identifica variables existentes
df_acuicultura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   codigoCentro               3228 non-null   int64
#  1   numPert                    3228 non-null   object
#  2   Comuna                     3228 non-null   object
#  3   Region                     3228 non-null   object
#  4   Titulares                  3228 non-null   object
#  5   NumeroResSSP               3228 non-null   int64
#  6   FechaResSSP                3228 non-null   object
#  7   ResultadoResolucionSSP     3228 non-null   object
#  8   NumeroResSSFFAA            3228 non-null   int64
#  9   FechaResSSFFAA             3228 non-null   object
#  10  ResultadoResolucionSSFFAA  3228 non-null   object
#  11  EspeciesPT                 3228 non-null   object
#  12  GrupoPT                    3228 non-null   object
# ...

# %% [markdown]
# Los siguientes gráficos serán generados para mostrar la frecuencia de cada valor de las columnas de este dataset. Debido a la cantidad de valores, se omitirán los gráficos para **codigoCentro**, **numPert**, **Titulares**, **NumeroResSSP**, **FechaResSSP**, **ResultadoResolucionSSP**, **NumeroResSSFFAA**, **FechaResSSFFAA**, **ResultadoResolucionSSFFAA**, **EspeciesPT**, **toponimio**. Debido a que la mayoría de las variables presentes en el dataset son cualitativas, esto limita el tipo de gráficos que son adecuados para visualizarlas.

# %%
df_acuicultura['Comuna'].value_counts().plot(kind='barh', figsize=(15,10)) 
plt.title("Distribución de concesiones de acuicultura por comuna")
plt.xlabel("Frecuencia")
plt.show()

# %% [markdown]
# Para la columna **Comuna** se eligió crear un gráfico de barras horizontal, debido a la cantidad de valores presentes. Este gráfico permite visualizar las comunas en las cuales existe
# una mayor y menor cantidad de concesiones de acuicultura.

# %%
df_acuicultura['Region'].value_counts().plot(kind='barh', figsize=(10,8)) 
plt.title("Distribución de concesiones de acuicultura por región")
plt.xlabel("Frecuencia")
plt.ylabel("Región")
plt.show()

# %% [markdown]
# Para la columna **Region** se eligió crear un gráfico de barras horizontal, debido a la concentración de muchas concesiones en pocas regiones. Este gráfico permite visualizar las regiones en las cuales existe una mayor y menor cantidad de concesiones de acuicultura.

# %%
df_acuicultura['Macrozona'].value_counts().plot(kind='bar', figsize=(6,8)) 
plt.title("Distribución de concesiones de acuicultura por macrozona")
plt.xlabel("Macrozona")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Para la columna **Macrozona** se eligió crear un gráfico de barras horizontal, debido a la concentración de las concesiones de acuicultura en las macrozonas sur y austral. Este gráfico permite visualizar las macrozonas en las cuales existe una mayor y menor cantidad de concesiones de acuicultura.

# %%
df_acuicultura['Tipo Titulares'].value_counts().plot(kind='barh', figsize=(8,6)) 
plt.title("Distribución de tipos de titulares de concesiones de acuicultura")
plt.xlabel("Frecuencia")
plt.show()

# %% [markdown]
# Para la columna **Tipo Titulares** se eligió crear un gráfico de barras horizontal, debido a que la mayoría de las concesiones de acuicultura pertenecen a empresas y personas naturales. Este gráfico permite visualizar la distribución de los tipos de titulares que poseen concesiones de acuicultura.

# %%
df_acuicultura['GrupoPT'].value_counts().plot(kind='barh', figsize=(9,7)) 
plt.title("Distribución de grupos de especies cultivadas en concesiones de acuicultura")
plt.xlabel("Frecuencia")
plt.ylabel("Grupo especie")
plt.show()

# %% [markdown]
# Para la columna **GrupoPT** se eligió crear un gráfico de barras horizontal, debido a que existen muchos conjuntos de grupos de especies cultivadas. Este gráfico permite visualizar la distribución de los conjuntos de especies cultivadas en concesiones de acuicultura.

# %%
colors_list = ['gold', 'skyblue', 'lightgreen', 'red']

df_acuicultura['GRUPO ESPECIE AGRUPADO'].value_counts().plot(
    kind='pie',
    figsize=(15,6),
    autopct='%1.1f%%',
    startangle=180,
    shadow=False,
    labels = ['Peces', 'Moluscos', 'Algas', 'Equinodermos'],
    colors=colors_list)


plt.title('Grupos generales especies acuicultura')
plt.ylabel("")
plt.axis('equal')
plt.show()

# %% [markdown]
# Para la columna **GRUPO ESPECIE AGRUPADO** se eligió crear un gráfico de pastel, debido a que existen pocos grupos generales de especies cultivadas. Este gráfico permite visualizar la distribución de los grupos generales de especies cultivadas en concesiones de acuicultura.

# %%
df_acuicultura['Tipo Toponimio'].value_counts().plot(kind='barh', figsize=(15,10)) 
plt.title("Distribución de tipos de toponimios")
plt.xlabel("Frecuencia")
plt.show()

# %% [markdown]
# Para la columna **Tipo Toponimio** se eligió crear un gráfico de barras horizontal, debido a la cantidad de valores presentes. Este gráfico permite visualizar la distribución los tipos de toponimios en los cuales se ubican las concesiones de acuicultura.

# %%
df_acuicultura['TipoPorcion'].value_counts().plot(kind='barh', figsize=(15,10)) 
plt.title("Distribución de tipos de porciones")
plt.xlabel("Frecuencia")
plt.ylabel("Tipo porción")
plt.show()

# %% [markdown]
# Para la columna **TipoPorcion** se eligió crear un gráfico de barras horizontal, debido a la cantidad de valores presentes. Este gráfico permite visualizar la distribución los tipos de porciones en los cuales se ubican las concesiones de acuicultura, comprobando que el tipo más común corresponde a agua y fondo.

# %%
#Histograma superficie total concesiones acuicultura
df_acuicultura.hist('superficieTotal')
plt.axvline(df_acuicultura['superficieTotal'].mean(), label="Media", ls="--", color="darkred")
plt.axvline(df_acuicultura['superficieTotal'].quantile(.25), label="percentil 25", ls="--", color="darkorange")
plt.axvline(df_acuicultura['superficieTotal'].quantile(.5), label="percentil 50", ls="--", color="darkorange")
plt.axvline(df_acuicultura['superficieTotal'].quantile(.75), label="percentil 75", ls="--", color="darkorange")
plt.axvline(df_acuicultura['superficieTotal'].quantile(.99), label="percentil 99", ls="--", color="darkorange")
plt.legend()
plt.xlabel("Superficie total concesión acuicultura (ha)")
plt.ylabel("Frecuencia")
plt.title("Superficie total concesiones acuicultura")
plt.show()

# %% [markdown]
# Para la columna **superficieTotal** se eligió crear un histograma, debido a que se trata de una variable numérica continua. Este gráfico permite visualizar la distribución de la superficie total de las concesiones de acuicultura.

# %%
sns.kdeplot(data=df_acuicultura, x="superficieTotal")
plt.xlabel("Superficie total concesión acuicultura (ha)")
plt.ylabel("Densidad de probabilidad")
plt.title("Superficie total concesiones acuicultura")
plt.show()

# %% [markdown]
# Para la columna **superficieTotal** se eligió crear un gráfico de Estimación de Densidad de Kernel, debido a que se trata de una variable numérica continua. Este gráfico permite visualizar la estimación de la densidad de probabilidad de la superficie total de las concesiones de acuicultura.

# %%
#Boxplot superficie total concesiones acuicultura
sns.violinplot(x=df_acuicultura["superficieTotal"])
plt.xlabel("Superficie total concesión acuicultura (ha)")
plt.title("Superficie total concesiones acuicultura")
plt.show()

# %% [markdown]
# Para la columna **superficieTotal** se eligió crear un diagrama de violín, debido a que se trata de una variable numérica continua. Este gráfico permite visualizar la distribución de los datos y la densidad de probabilidad de la superficie total de las concesiones de acuicultura.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="Tipo Titulares", hue = "Macrozona")
plt.title("Distribución de superficie total (ha) por tipo de titular")
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo titular")
plt.legend(loc=(1.04, 0))
plt.show()

# %% [markdown]
# En este gráfico se compara la distribución de la superficie total en hectáreas para cada tipo de titular de concesión de acuicultura, mientras que el color de cada punto representa a la macrozona en la cual se encuentra una concesión específica. Las empresas tienen el mayor rango de superficie en comparación a todos los otros tipos de titulares. La empresa que tiene la concesión de mayor superficie cultiva en la macrozona norte.
#
# Observando el gráfico se puede concluir que en general los concesionarios cultivan en la macrozona sur. Las asociaciones gremiales tienen más concesiones en la macrozona centro norte.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="Tipo Titulares", hue = "GRUPO ESPECIE AGRUPADO")
plt.title("Distribución de superficie total (ha) por tipo de titular")
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo titular")
plt.legend(loc=(1.04, 0))
plt.show()

# %% [markdown]
# En este gráfico se compara la distribución de la superficie total en hectáreas para cada tipo de titular de concesión de acuicultura, mientras que el color de cada punto representa al grupo de especies cultivado en una concesión específica. Las empresas poseen la mayor variedad de grupos de especies cultivados, mientras que las asociaciones gremiales cultivan moluscos. Las personas naturales, sindicatos, cooperativas, y municipalidades cultivan algas y moluscos.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="TipoPorcion", hue ="Macrozona")
plt.title("Distribución de superficie total (ha) por tipo de porción")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo porción")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de porciones usados por las concesiones de acuicultura, mientras que el color de los puntos representa a la macrozona en la cual se ubica una concesión. El tipo de porción con el mayor rango de superficie total es agua y fondo, lo cual concuerda con la cantidad de concesiones ubicadas en ese tipo de porción.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="TipoPorcion", hue ="Tipo Titulares")
plt.title("Distribución de superficie total (ha) por tipo de porción")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo porción")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de porciones usados por las concesiones de acuicultura, mientras que el color de los puntos representa a al tipo de titular de una concesión. Se observan concesiones empresariales y de personas naturales en el caso de agua y fondo.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="TipoPorcion", hue ="GRUPO ESPECIE AGRUPADO")
plt.title("Distribución de superficie total (ha) por tipo de porción")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo porción")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de porciones usados por las concesiones de acuicultura, mientras que el color de los puntos representa a al grupo de especies cultivado en una concesión. Se observa que en agua y fondo se cultivan todos los grupos de especies, lo cual explicaría que la mayoría de las concesiones utilicen dicho tipo de porción para sus concesiones.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="Tipo Toponimio",  hue = "Macrozona")
plt.title("Distribución de superficie total (ha) por tipo de toponimio")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo toponimio")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de toponimios en los cuales se localizan las concesiones de acuicultura, mientras que el color de los puntos representa a la macrozona en la cual se ubica una concesión. El tipo de porción con el mayor rango de superficie total es bahía. La macrozona sur tiene la mayor variedad de tipos de toponimio.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="Tipo Toponimio",  hue = "Tipo Titulares")
plt.title("Distribución de superficie total (ha) por tipo de toponimio")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo toponimio")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de toponimios en los cuales se localizan las concesiones de acuicultura, mientras que el color de los puntos representa al tipo de titular que posee una concesión. El tipo de titular empresa se encuentra en la mayor cantidad de tipos de toponimios del dataset.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="Tipo Toponimio", hue = "GRUPO ESPECIE AGRUPADO")
plt.title("Distribución de superficie total (ha) por tipo de toponimio")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Tipo toponimio")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total de distintos tipos de toponimios en los cuales se localizan las concesiones de acuicultura, mientras que el color de los puntos representa al grupo de especies cultivado en una concesión. En el tipo de toponimio río se cultuvan algas y peces. En el caso de los lagos sólo existen concesiones que cultivan peces, mientras que en laguna se cultivan moluscos.
#
# Los peces y moluscos se cultivan en varios tipos de toponimios.

# %%
sns.stripplot(data=df_acuicultura, x="superficieTotal", y="GRUPO ESPECIE AGRUPADO", hue = "Macrozona")
plt.title("Distribución de superficie total (ha) por grupo de especie cultivado")
plt.legend(loc=(1.04, 0))
plt.xlabel("Superficie total (ha)")
plt.ylabel("Grupo especie")
plt.show()

# %% [markdown]
# En este gráfico se compara la superficie total utilizada para el cultivo de distintos grupos de especies en las macrozonas chilenas. En la concesión de mayor superficie se cultivan moluscos. La única concesión de equinodermos se encuentra ubicada en la macrozona centro norte.
