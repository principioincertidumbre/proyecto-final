# %%
import numpy as np
import pandas as pd

# %%
df_acuicultura = pd.read_csv("concesiones_acuicultura_sin_nulos.csv")

# %%
#Identifica variables existentes
df_acuicultura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   codigoCentro               3228 non-null   int64
#  1   numPert                    3228 non-null   object
#  2   Comuna                     3228 non-null   object
#  3   Region                     3228 non-null   object
#  4   Titulares                  3228 non-null   object
#  5   NumeroResSSP               3228 non-null   int64
#  6   FechaResSSP                3228 non-null   object
#  7   ResultadoResolucionSSP     3228 non-null   object
#  8   NumeroResSSFFAA            3228 non-null   int64
#  9   FechaResSSFFAA             3228 non-null   object
#  10  ResultadoResolucionSSFFAA  3228 non-null   object
#  11  EspeciesPT                 3228 non-null   object
#  12  GrupoPT                    3228 non-null   object
# ...

# %%
df_acuicultura.head()
# Out:
#    codigoCentro    numPert                          Comuna  \
# 0         90201  200091005  CARAHUE
# 1        104477  219101021  MAULLIN
# 2        104476  207105039  ANCUD
# 3        104475  206101181  MAULLIN
# 4        104473  209103041  QUEMCHI
#
#                    Region                                          Titulares  \
# 0  REGIÓN DE LA ARAUCANÍA         5692719-0: AVILA GALDAMES, HECTOR FERNANDO
# 1     REGIÓN DE LOS LAGOS          18844230-7: VARGAS MANSILLA MARIA IGNACIA
# 2     REGIÓN DE LOS LAGOS         71780900-9: SINDICATO TRABAJADORES CHAULAR
# 3     REGIÓN DE LOS LAGOS  10512152-0: CARDENAS BUSTAMANTE, ROBINSON EFIL...
# 4     REGIÓN DE LOS LAGOS  10121206-8: PEÑA IMILMAQUI, JUAN VICTOR, 11595...
#
#    NumeroResSSP FechaResSSP ResultadoResolucionSSP  NumeroResSSFFAA  \
# 0          1122  2023-05-08                Aprueba              441
# 1          2111  2022-10-18                Aprueba               39
# ...

# %% [markdown]
# Al analizar las variables presentes en este dataset, a partir de la columna **Titulares** se puede crear la columna **Tipo Titulares** para clasificar a cada concesionaro dentro de un grupo general, facilitando realizar visualizaciones posteriormente. Además, es posible crear la columna **Macrozona** a partir de la columna **Region** para obtener una clasificación general, **Tipo Toponimio** para clasificar de forma general los lugares mencionados en la columna **toponimio**.

# %%
#Crea columna Tipo Titulares
df_acuicultura["Tipo Titulares"] = "" 

df_acuicultura
# Out:
#       codigoCentro    numPert                          Comuna  \
# 0            90201  200091005  CARAHUE
# 1           104477  219101021  MAULLIN
# 2           104476  207105039  ANCUD
# 3           104475  206101181  MAULLIN
# 4           104473  209103041  QUEMCHI
# ...            ...        ...                             ...
# 3223         40097  900001000  COQUIMBO
# 3224        100304  900000018  CORRAL
# 3225        100332  900000040  LLANQUIHUE
# 3226        100338  900000004  ANCUD
# 3227        100336  900000005  ANCUD
#
#                       Region  \
# 0     REGIÓN DE LA ARAUCANÍA
# 1        REGIÓN DE LOS LAGOS
# 2        REGIÓN DE LOS LAGOS
# 3        REGIÓN DE LOS LAGOS
# 4        REGIÓN DE LOS LAGOS
# ...                      ...
# 3223      REGIÓN DE COQUIMBO
# 3224      REGIÓN DE LOS RÍOS
# 3225     REGIÓN DE LOS LAGOS
# 3226     REGIÓN DE LOS LAGOS
# 3227     REGIÓN DE LOS LAGOS
#
#                                               Titulares  NumeroResSSP  \
# ...

# %% [markdown]
# Para evitar errores al completar los datos de la columna **Tipo Titulares** se reemplazan las siguientes siglas con el nombre correspondiente al tipo de agrupación.

# %%
df_acuicultura['Titulares'] = df_acuicultura['Titulares'].str.replace("A. G.","ASOCIACION GREMIAL")

# %%
df_acuicultura['Titulares'] = df_acuicultura['Titulares'].str.replace("S.A.","SOCIEDAD ANONIMA")

# %%
df_acuicultura['Titulares'] = df_acuicultura['Titulares'].str.replace("S.T.I.","SINDICATO")

# %%
df_acuicultura['Titulares'] = df_acuicultura['Titulares'].str.replace("E.I.R.L.","EMPRESA INDIVIDUAL RESPONSABILIDAD LIMITADA")

# %%
#Agrega datos de tipo titular a la columna correspondiente
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SOCIEDAD ANONIMA'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SPA'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SINDICATO'), 'Tipo Titulares'] = 'Sindicato'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SIND'), 'Tipo Titulares'] = 'Sindicato'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SIN. TRAB.'), 'Tipo Titulares'] = 'Sindicato'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('LTDA'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('ASOCIACION GREMIAL'), 'Tipo Titulares'] = 'Asociación Gremial'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('COOP.'), 'Tipo Titulares'] = 'Cooperativa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SOCIEDAD'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('SOCIEDAD'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('MUNICIPALIDAD'), 'Tipo Titulares'] = 'Municipalidad'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('U. VECINAL'), 'Tipo Titulares'] = 'Unidad Vecinal'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('COMITE PRODUCTIVO'), 'Tipo Titulares'] = 'Comité Productivo'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('LIMITADA'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('CORPORACION MUNICIPAL'), 'Tipo Titulares'] = 'Corporación Municipal'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('UNIVERSIDAD'), 'Tipo Titulares'] = 'Universidad'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('COOPERATIVA DE TRABAJO'), 'Tipo Titulares'] = 'Cooperativa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('EMPRESA INDIVIDUAL RESPONSABILIDAD LIMITADA'), 'Tipo Titulares'] = 'Empresa'
df_acuicultura.loc[df_acuicultura['Titulares'].str.contains('FUNDACION'), 'Tipo Titulares'] = 'Fundación'

# %%
#Reemplaza espacios vacíos con NAs para posteriormente reemplazarlos con un tipo de titular
df_acuicultura = df_acuicultura.replace(r'^\s*$', np.nan, regex=True)

# %%
df_acuicultura['Tipo Titulares'] = df_acuicultura['Tipo Titulares'].fillna("Persona natural")

# %%
#Verifica que aparezcan todos los tipos de titulares
df_acuicultura['Tipo Titulares'].value_counts()
# Out:
# Tipo Titulares
# Empresa                  2081
# Persona natural          1012
# Sindicato                  87
# Asociación Gremial         13
# Universidad                12
# Cooperativa                 8
# Municipalidad               5
# Fundación                   5
# Corporación Municipal       3
# Unidad Vecinal              1
# Comité Productivo           1
# Name: count, dtype: int64

# %%
#Crea columna Macrozona
df_acuicultura["Macrozona"] = "" 

df_acuicultura
# Out:
#       codigoCentro    numPert                          Comuna  \
# 0            90201  200091005  CARAHUE
# 1           104477  219101021  MAULLIN
# 2           104476  207105039  ANCUD
# 3           104475  206101181  MAULLIN
# 4           104473  209103041  QUEMCHI
# ...            ...        ...                             ...
# 3223         40097  900001000  COQUIMBO
# 3224        100304  900000018  CORRAL
# 3225        100332  900000040  LLANQUIHUE
# 3226        100338  900000004  ANCUD
# 3227        100336  900000005  ANCUD
#
#                       Region  \
# 0     REGIÓN DE LA ARAUCANÍA
# 1        REGIÓN DE LOS LAGOS
# 2        REGIÓN DE LOS LAGOS
# 3        REGIÓN DE LOS LAGOS
# 4        REGIÓN DE LOS LAGOS
# ...                      ...
# 3223      REGIÓN DE COQUIMBO
# 3224      REGIÓN DE LOS RÍOS
# 3225     REGIÓN DE LOS LAGOS
# 3226     REGIÓN DE LOS LAGOS
# 3227     REGIÓN DE LOS LAGOS
#
#                                               Titulares  NumeroResSSP  \
# ...

# %%
#Agrega datos de macrozona a la columna correspondiente
df_acuicultura.loc[df_acuicultura['Region'].str.contains('LOS LAGOS'), 'Macrozona'] = 'Sur'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('AYSÉN'), 'Macrozona'] = 'Austral'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('MAGALLANES'), 'Macrozona'] = 'Austral'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('ARAUCANÍA'), 'Macrozona'] = 'Centro Sur'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('ATACAMA'), 'Macrozona'] = 'Norte'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('COQUIMBO'), 'Macrozona'] = 'Centro Norte'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('LOS RÍOS'), 'Macrozona'] = 'Sur'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('TARAPACA'), 'Macrozona'] = 'Norte'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('BIOBÍO'), 'Macrozona'] = 'Centro Sur'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('ANTOFAGASTA'), 'Macrozona'] = 'Norte'
df_acuicultura.loc[df_acuicultura['Region'].str.contains('MAULE'), 'Macrozona'] = 'Centro Sur'
df_acuicultura.loc[df_acuicultura['Region'].str.contains("O'HIGGINS"), 'Macrozona'] = 'Centro Norte'

# %%
df_acuicultura['Macrozona'].value_counts()
# Out:
# Macrozona
# Sur             2169
# Austral          870
# Centro Sur        73
# Norte             72
# Centro Norte      44
# Name: count, dtype: int64

# %%
#Crea dataframe para dividir columna toponimio
df_acuicultura_toponimo = df_acuicultura['toponimio'].str.split(",", expand=True)

# %%
df_acuicultura_toponimo
# Out:
#                                  0   \
# 0                 (1): RÍO IMPERIAL
# 1     (1): RIO MAULLIN RIBERA NORTE
# 2               (1): ESTERO CHAULAR
# 3                  (1): RÍO QUENUIR
# 4             (1): ESTERO BUTATIQUE
# ...                             ...
# 3223              (1): BAHÍA TONGOY
# 3224        (1): RÍO TORNA GALEONES
# 3225           (1): LAGO LLANQUIHUE
# 3226             (1): BAHÍA HUEIHUE
# 3227                (1): RÍO PUDETO
#
#                                                   1                     2   \
# 0                       AL OESTE DE SECTOR SAN PABLO                  None
# 1                                         PARCELA R4                  None
# 2      AL OESTE DE PUNTA LARGA. PENÍNSULA GUAPILACUI   (2): ESTERO CHAULAR
# 3                                     SECTOR QUENUIR                  None
# 4                            AL ESTE DE ISLA CHEMLLI     ISLA BUTACHAUQUES
# ...

# %%
df_acuicultura_toponimo[0].value_counts()
# Out:
# 0
# (1): RIO MAULLIN RIBERA NORTE    140
# (1): RIO MAULLÍN RIBERA NORTE    109
# (1): CANAL HUDSON                 67
# (1): ESTERO YALDAD                59
# (1): CANAL YAL                    54
#                                 ...
# (1): CALETA ALFARO                 1
# (1): ALDACHILDO                    1
# (1): NORTE DE CHAIQUEN             1
# (1): PUNTA YUTUY                   1
# (1): LLIUCO                        1
# Name: count, Length: 854, dtype: int64

# %%
#Crea columna Tipo Toponimio
df_acuicultura["Tipo Toponimio"] = "" 

df_acuicultura
# Out:
#       codigoCentro    numPert                          Comuna  \
# 0            90201  200091005  CARAHUE
# 1           104477  219101021  MAULLIN
# 2           104476  207105039  ANCUD
# 3           104475  206101181  MAULLIN
# 4           104473  209103041  QUEMCHI
# ...            ...        ...                             ...
# 3223         40097  900001000  COQUIMBO
# 3224        100304  900000018  CORRAL
# 3225        100332  900000040  LLANQUIHUE
# 3226        100338  900000004  ANCUD
# 3227        100336  900000005  ANCUD
#
#                       Region  \
# 0     REGIÓN DE LA ARAUCANÍA
# 1        REGIÓN DE LOS LAGOS
# 2        REGIÓN DE LOS LAGOS
# 3        REGIÓN DE LOS LAGOS
# 4        REGIÓN DE LOS LAGOS
# ...                      ...
# 3223      REGIÓN DE COQUIMBO
# 3224      REGIÓN DE LOS RÍOS
# 3225     REGIÓN DE LOS LAGOS
# 3226     REGIÓN DE LOS LAGOS
# 3227     REGIÓN DE LOS LAGOS
#
#                                               Titulares  NumeroResSSP  \
# ...

# %%
#Agrega datos de tipo toponimio a la columna correspondiente
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('RÍO'), 'Tipo Toponimio'] = 'Río'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('RIO'), 'Tipo Toponimio'] = 'Río'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ESTERO'), 'Tipo Toponimio'] = 'Estero'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CALETA'), 'Tipo Toponimio'] = 'Caleta'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ENSENADA'), 'Tipo Toponimio'] = 'Ensenada'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CANAL'), 'Tipo Toponimio'] = 'Canal'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('SENO'), 'Tipo Toponimio'] = 'Seno'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LLIUCO'), 'Tipo Toponimio'] = 'Aldea'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ISLA'), 'Tipo Toponimio'] = 'Isla'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAHÍA'), 'Tipo Toponimio'] = 'Bahía'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PENÍNSULA'), 'Tipo Toponimio'] = 'Península'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PASO'), 'Tipo Toponimio'] = 'Paso'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PUERTO'), 'Tipo Toponimio'] = 'Puerto'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('FIORDO'), 'Tipo Toponimio'] = 'Fiordo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ESTUARIO'), 'Tipo Toponimio'] = 'Estuario'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PUNTA'), 'Tipo Toponimio'] = 'Punta'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BRAZO'), 'Tipo Toponimio'] = 'Brazo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ESTRECHO'), 'Tipo Toponimio'] = 'Estrecho'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUETALCO'), 'Tipo Toponimio'] = 'Villorrio'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LINCAI'), 'Tipo Toponimio'] = 'Bahía'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('GOLFO'), 'Tipo Toponimio'] = 'Golfo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('HUYAR'), 'Tipo Toponimio'] = 'Pueblo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('Bancos'), 'Tipo Toponimio'] = 'Banco'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PIEDRA  AZUL'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUIDICO'), 'Tipo Toponimio'] = 'Caleta'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ROCA COCHETAHUE'), 'Tipo Toponimio'] = 'Roca'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LA PLANCHADA'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('NORTE DE CALAMACO'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('EL CANUTILLAR'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('SECT PUCHEGUIN'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUELLÓN VIEJO'), 'Tipo Toponimio'] = 'Poblado'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('MATAO'), 'Tipo Toponimio'] = 'Distrito'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LLUCURA'), 'Tipo Toponimio'] = 'Pueblo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CARAHUE'), 'Tipo Toponimio'] = 'Ciudad'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ISLOTE'), 'Tipo Toponimio'] = 'Islote'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('SECTOR ENTRE ISLA LLINGUA'), 'Tipo Toponimio'] = 'Bahía'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUINCHED'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CALEN'), 'Tipo Toponimio'] = 'Pueblo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUIQUEL'), 'Tipo Toponimio'] = 'Localidad'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('SECTOR TRINCAO'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ROCA NEGRA'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAJO CHAUQUES'), 'Tipo Toponimio'] = 'Isla'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAJO MEULÍN'), 'Tipo Toponimio'] = 'Isla'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BANCOS'), 'Tipo Toponimio'] = 'Banco'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('SECTOR YERBAS BUENAS'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ROCA VERDE'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CULULIR'), 'Tipo Toponimio'] = 'Localidad'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUILILPUE'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LAGUNA'), 'Tipo Toponimio'] = 'Laguna'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('ALDACHILDO'), 'Tipo Toponimio'] = 'Pueblo'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LA FABRICA'), 'Tipo Toponimio'] = 'Localidad'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BARRANCO COCHE'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('QUINCHAO'), 'Tipo Toponimio'] = 'Isla'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PELDEHUE'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('COSTA'), 'Tipo Toponimio'] = 'Costa'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('RADA'), 'Tipo Toponimio'] = 'Bahía'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('MORRO LOBOS'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PLAYA'), 'Tipo Toponimio'] = 'Playa'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAJO SALVO'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAJO CHINCUI'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAHIA'), 'Tipo Toponimio'] = 'Bahía'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('BAJO LA BARRA'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('PIEDRA LILECURA'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('LAGO'), 'Tipo Toponimio'] = 'Lago'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('CHAIQUEN'), 'Tipo Toponimio'] = 'Sector'
df_acuicultura.loc[df_acuicultura_toponimo[0].str.contains('MORRO CHICO'), 'Tipo Toponimio'] = 'Sector'

# %%
df_acuicultura['Tipo Toponimio'].value_counts()
# Out:
# Tipo Toponimio
# Canal        855
# Estero       569
# Río          479
# Bahía        257
# Punta        224
# Isla         190
# Seno         122
# Ensenada      88
# Paso          72
# Caleta        55
# Puerto        48
# Sector        45
# Fiordo        32
# Península     30
# Golfo         29
# Lago          29
# Pueblo        25
# Villorrio     22
# Poblado       14
# Localidad      8
# Islote         7
# Costa          6
# Banco          4
# Playa          4
# Distrito       4
# Laguna         2
# Brazo          2
# Estuario       1
# Aldea          1
# Estrecho       1
# Roca           1
# Ciudad         1
#                1
# Name: count, dtype: int64
